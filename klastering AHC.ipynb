# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("INTELLIGENT.csv")
print(data)
# Out:
#      moisture  temp  pump
# 0         638    16     1
# 1         522    18     1
# 2         741    22     1
# 3         798    32     1
# 4         690    28     1
# ..        ...   ...   ...
# 195       941    13     1
# 196       902    45     1
# 197       894    42     1
# 198      1022    45     1
# 199       979    10     1
#
# [200 rows x 3 columns]

# %%
x = np.asarray(data)
print(x)
# Out:
# [[ 638   16    1]
#  [ 522   18    1]
#  [ 741   22    1]
#  [ 798   32    1]
#  [ 690   28    1]
#  [ 558   23    1]
#  [ 578   12    1]
#  [ 673   35    1]
#  [ 642   45    1]
#  [ 723   11    1]
#  [ 671   23    1]
#  [ 758   34    1]
#  [ 507   45    1]
#  [ 586   33    1]
#  [ 703   45    1]
#  [ 716   25    1]
#  [ 724   11    1]
#  [ 828   41    1]
#  [ 633   23    1]
#  [ 783   18    1]
#  [ 635   36    1]
#  [ 525   33    1]
#  [ 636   24    1]
#  [ 813   15    1]
#  [ 736   44    1]
#  [ 833   13    1]
#  [ 808   29    1]
#  [ 714   14    1]
#  [ 806   28    1]
#  [ 681   31    1]
#  [ 661   35    1]
#  [ 546   32    1]
#  [ 759   10    1]
#  [ 803   21    1]
#  [ 670   22    1]
#  [ 796   21    1]
#  [ 665   32    1]
#  [ 687   11    1]
#  [ 573   13    1]
#  [ 812   38    1]
#  [ 698   45    1]
#  [ 675   39    1]
#  [ 700   38    1]
#  [ 749   38    1]
#  [ 537   44    1]
#  [ 748   27    1]
#  [ 824   37    1]
#  [ 839   29    1]
#  [ 740   31    1]
#  [ 533   42    1]
# ...

# %%
z = linkage(x)

# %%
print(z)
# Out:
# [[  9.          16.           1.           2.        ]
#  [ 10.          34.           1.41421356   2.        ]
#  [ 70.          78.           1.41421356   2.        ]
#  [174.         188.           1.41421356   2.        ]
#  [177.         203.           1.41421356   3.        ]
#  [173.         197.           2.           2.        ]
#  [134.         146.           2.           2.        ]
#  [  0.          52.           2.23606798   2.        ]
#  [ 26.          28.           2.23606798   2.        ]
#  [ 47.          97.           2.23606798   2.        ]
#  [165.         192.           2.23606798   2.        ]
#  [164.         169.           2.23606798   2.        ]
#  [101.         130.           2.23606798   2.        ]
#  [  6.          54.           2.82842712   2.        ]
#  [110.         145.           2.82842712   2.        ]
#  [ 68.          92.           3.           2.        ]
#  [159.         161.           3.           2.        ]
# ...

# %%
plt.figure(figsize=(25, 10))
plt.title('Dendogram Hierarchical Klastering')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(z)
plt.show()
